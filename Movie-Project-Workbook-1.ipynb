# %%
import requests
import json

# %%
import time

# %%
import pandas as pd

# %%
import numpy as np

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
tmdb = TMDb()
tmdb.api_key = '69b1bbc66e37773ea1cc0568b2898163'

# %%
from tmdbv3api import Movie
from tmdbv3api import Discover
discover = Discover()
movie = Movie()

# %%
import mysql.connector 
import config

# %%
cnx = mysql.connector .connect(
    host = config.host,
    user = config.user,
    passwd = config.pw)

# %%
cursor = cnx.cursor()

# %%
cnx.database = 'movie_analysis_project'

# %%
cursor

# %%
print(show)
# Out:
# [The Irishman, Rambo: Last Blood, Joker, Ip Man 4: The Finale, Once Upon a Time… in Hollywood, It Chapter Two, Hustlers, Marriage Story, The Lion King, Parasite, Ford v Ferrari, Downton Abbey, El Camino: A Breaking Bad Movie, Last Christmas, Interstellar, The Report, Gundala, Spider-Man: Homecoming, Freaks, Léon: The Professional]

# %%
print(movie.with_genres())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-1d923fbd8fb7> in <module>
# ----> 1 print(movie.with_genres())
#
# AttributeError: 'Movie' object has no attribute 'with_genres'

# %%
response = requests.get('https://api.themoviedb.org/3//discover/movie?sort_by=genre.desc?api_key=69b1bbc66e37773ea1cc0568b2898163')

# %%
list(response)
# Out:
# [b'{"status_code":7,"status_message":"Invalid API key: You must be granted a valid key.","success":false}\n']

# %%
#url = 'https://api.themoviedb.org/3/discover/movie?with_genres=18?api_key=69b1bbc66e37773ea1cc0568b2898163'

# %%
response = requests.get(url = 'https://api.themoviedb.org/3/discover/movie?with_genres=18?api_key=69b1bbc66e37773ea1cc0568b2898163')

# %%
response
# Out:
# <Response [401]>

# %%
api_key = '69b1bbc66e37773ea1cc0568b2898163'

# %%
#headers = {
        'Authorization': 'Bearer f"{api_key}"',
        'Content Type' : 'application/json;charset=utf-8'
    }

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/genre/movie/list?language=en-US&api_key=69b1bbc66e37773ea1cc0568b2898163", payload)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}

# %%
genre_dict = json.loads(data)

# %%
genre_dict
# Out:
# {'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 16, 'name': 'Animation'},
#   {'id': 35, 'name': 'Comedy'},
#   {'id': 80, 'name': 'Crime'},
#   {'id': 99, 'name': 'Documentary'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 14, 'name': 'Fantasy'},
#   {'id': 36, 'name': 'History'},
#   {'id': 27, 'name': 'Horror'},
#   {'id': 10402, 'name': 'Music'},
#   {'id': 9648, 'name': 'Mystery'},
#   {'id': 10749, 'name': 'Romance'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 10770, 'name': 'TV Movie'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 10752, 'name': 'War'},
#   {'id': 37, 'name': 'Western'}]}

# %%
show = discover.discover_movies({'with_genres': 28})

# %%
len(show)
# Out:
# 20

# %%
movie = Movie()
popular = movie.popular()

for p in popular:
    print(p.id)
    print(p.title)
# Out:
# 330457
# Frozen II
# 512200
# Jumanji: The Next Level
# 419704
# Ad Astra
# 398978
# The Irishman
# 522938
# Rambo: Last Blood
# 475557
# Joker
# 449924
# Ip Man 4: The Finale
# 466272
# Once Upon a Time… in Hollywood
# 290859
# Terminator: Dark Fate
# 474350
# It Chapter Two
# 431580
# Abominable
# 546554
# Knives Out
# 540901
# Hustlers
# 920
# Cars
# 492188
# Marriage Story
# 641790
# Trauma Center
# 420817
# Aladdin
# 384018
# Fast & Furious Presents: Hobbs & Shaw
# 299536
# Avengers: Infinity War
# 540247
# Jurassic Galaxy
# 20

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

Movie_data_list=[]

for movies in movie_id_list:
payload = "{}"

conn.request("GET", "/3/movie/{movie_id}?language=en-US&api_key=69b1bbc66e37773ea1cc0568b2898163", payload)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"status_code":25,"status_message":"Your request count (84) is over the allowed limit of 40."}

# %%
#1 API Call Function
def api_call(url):
    response = requests.get(url)
    data = response.json()
    movies = data['movies']
    return movies

# %%
#4
def paginate(url_params, headers, url):
    cur = 0
    while cur < 1000:
        url_params['offset'] = cur
        businesses = api_call(url, headers, url_params)
        parsed_data = parse_data(businesses)
        insert_func(cnx, cursor, parsed_data)
        cur += 50

# %%
conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/collection/%7Bcollection_id%7D?language=en-US&api_key=69b1bbc66e37773ea1cc0568b2898163", payload)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"status_code":25,"status_message":"Your request count (69) is over the allowed limit of 40."}

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/movie/%7Bmovie_id%7D/external_ids?api_key=69b1bbc66e37773ea1cc0568b2898163", payload)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"status_code":25,"status_message":"Your request count (111) is over the allowed limit of 40."}

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/discover/movie?year=2018&include_video=false&include_adult=false&sort_by=release_date.desc&region=US&language=en-US&api_key=69b1bbc66e37773ea1cc0568b2898163", payload)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"page":1,"total_results":6366,"total_pages":319,"results":[{"popularity":1.4,"id":565979,"video":false,"vote_count":1,"vote_average":10,"title":"The Sunday Night Slaughter","release_date":"2018-12-31","original_language":"en","original_title":"The Sunday Night Slaughter","genre_ids":[],"backdrop_path":null,"adult":false,"overview":"An anthology horror film featuring three stories involving demons, cannibals, psychopaths and demigods all intertwined, taking place in the final 31 days of earth.","poster_path":"\/a9inU5TjKfP1AzUyTVR43m3vXwA.jpg"},{"popularity":0.672,"id":580468,"video":false,"vote_count":1,"vote_average":10,"title":"Little Hero y los amuletos mágicos","release_date":"2018-12-31","original_language":"es","original_title":"Little Hero y los amuletos mágicos","genre_ids":[16],"backdrop_path":null,"adult":false,"overview":"LITTLE HERO is about a young boy's quest to save his father from an ancient monster. When BAYU finds a sword, he accidentally awakens the giant evil Asu
# ...

# %%
data
# Out:
# [123,
#  34,
#  112,
#  97,
#  103,
#  101,
#  34,
#  58,
#  49,
#  44,
#  34,
#  116,
#  111,
#  116,
#  97,
#  108,
#  95,
#  114,
#  101,
#  115,
#  117,
#  108,
#  116,
#  115,
#  34,
#  58,
#  54,
#  51,
#  54,
#  54,
#  44,
#  34,
#  116,
#  111,
#  116,
#  97,
#  108,
#  95,
#  112,
#  97,
#  103,
#  101,
#  115,
#  34,
#  58,
#  51,
#  49,
#  57,
#  44,
#  34,
#  114,
#  101,
#  115,
#  117,
#  108,
#  116,
#  115,
#  34,
#  58,
#  91,
#  123,
#  34,
#  112,
#  111,
#  112,
#  117,
#  108,
#  97,
#  114,
#  105,
#  116,
#  121,
#  34,
#  58,
#  49,
#  46,
#  52,
#  44,
#  34,
#  105,
#  100,
#  34,
#  58,
#  53,
#  54,
#  53,
#  57,
#  55,
#  57,
#  44,
#  34,
#  118,
#  105,
#  100,
#  101,
#  111,
#  34,
#  58,
#  102,
#  97,
#  108,
#  115,
#  101,
#  44,
#  34,
#  118,
#  111,
#  116,
#  101,
#  95,
#  99,
#  111,
#  117,
#  110,
#  116,
#  34,
#  58,
#  49,
#  44,
#  34,
#  118,
#  111,
#  116,
#  101,
#  95,
#  97,
#  118,
#  101,
#  114,
#  97,
#  103,
#  101,
#  34,
# ...

# %%
data_dict=json.loads(data)

# %%
data_dict
# Out:
# {'page': 1,
#  'total_results': 6366,
#  'total_pages': 319,
#  'results': [{'popularity': 1.4,
#    'id': 565979,
#    'video': False,
#    'vote_count': 1,
#    'vote_average': 10,
#    'title': 'The Sunday Night Slaughter',
#    'release_date': '2018-12-31',
#    'original_language': 'en',
#    'original_title': 'The Sunday Night Slaughter',
#    'genre_ids': [],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'An anthology horror film featuring three stories involving demons, cannibals, psychopaths and demigods all intertwined, taking place in the final 31 days of earth.',
#    'poster_path': '/a9inU5TjKfP1AzUyTVR43m3vXwA.jpg'},
#   {'popularity': 0.672,
#    'id': 580468,
#    'video': False,
#    'vote_count': 1,
#    'vote_average': 10,
#    'title': 'Little Hero y los amuletos mágicos',
#    'release_date': '2018-12-31',
#    'original_language': 'es',
#    'original_title': 'Little Hero y los amuletos mágicos',
#    'genre_ids': [16],
# ...

# %%
data_dict.keys()
# Out:
# dict_keys(['page', 'total_results', 'total_pages', 'results'])

# %%
data_dict['results'][0]
# Out:
# {'popularity': 1.4,
#  'id': 565979,
#  'video': False,
#  'vote_count': 1,
#  'vote_average': 10,
#  'title': 'The Sunday Night Slaughter',
#  'release_date': '2018-12-31',
#  'original_language': 'en',
#  'original_title': 'The Sunday Night Slaughter',
#  'genre_ids': [],
#  'backdrop_path': None,
#  'adult': False,
#  'overview': 'An anthology horror film featuring three stories involving demons, cannibals, psychopaths and demigods all intertwined, taking place in the final 31 days of earth.',
#  'poster_path': '/a9inU5TjKfP1AzUyTVR43m3vXwA.jpg'}

# %%
movie = data_dict['results'][0]

# %%
movie_tuple = (movie['id'], movie['title'], movie['release_date'], movie['genre_ids'], movie['popularity'])

# %%
movie_tuple
# Out:
# (565979, 'The Sunday Night Slaughter', '2018-12-31', [], 1.4)

# %%
#def parse_data(data_list):
parsed_data_list = []
for movie in data_dict['results']:
   # try:
    movie_tuple = (movie['id'], movie['title'], movie['release_date'], movie['genre_ids'], movie['popularity'])
    parsed_data_list.append(movie_tuple)
    #except:
        #movie_tuple = (movie['id'], movie['title'], movie['release_date'], 0 , movie['popularity'])
        #parsed_data_list.append(movie_tuple)

# %%
parsed_data_list
# Out:
# [(565979, 'The Sunday Night Slaughter', '2018-12-31', [], 1.4),
#  (580468, 'Little Hero y los amuletos mágicos', '2018-12-31', [16], 0.672),
#  (613492, '2 Gentlemen of Verona', '2018-12-31', [], 1.4),
#  (568332,
#   'Taylor Swift: Reputation Stadium Tour',
#   '2018-12-31',
#   [99, 10402],
#   9.548),
#  (591788, 'D.J. Demers: [Indistinct Chatter]', '2018-12-31', [35], 0.6),
#  (592126, 'Ian Bagg: Conversations', '2018-12-31', [35], 0.6),
#  (494113, 'Infected', '2018-12-31', [53, 27], 1.195),
#  (627948, 'Dinotasia Dinosaur Chronicle', '2018-12-31', [], 0.6),
#  (429724, 'Browse', '2018-12-31', [27, 53], 0.6),
#  (437518,
#   'Friend of the World',
#   '2018-12-31',
#   [35, 18, 27, 878, 53, 10752],
#   0.6),
#  (445466, 'The Shitheads', '2018-12-31', [35], 0.6),
#  (504844, 'Tyler Boeh: Wait For It', '2018-12-31', [35], 0.6),
#  (513384, 'Medicine Men', '2018-12-31', [18], 0.685),
#  (523861, 'Green River: Part Three', '2018-12-31', [18, 9648], 0.6),
# ...

# %% [markdown]
# ########################################################################################

# %% [markdown]
# #################################### Data Exploration ########################################

# %%
import http.client

conn = http.client.HTTPSConnection("api.themoviedb.org")

payload = "{}"

conn.request("GET", "/3/discover/movie?year=2018&page=1&include_video=false&include_adult=false&sort_by=revenue.desc&region=US&language=en-US&api_key=69b1bbc66e37773ea1cc0568b2898163", payload)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"page":1,"total_results":6367,"total_pages":319,"results":[{"popularity":84.433,"vote_count":15979,"video":false,"poster_path":"\/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg","id":299536,"adult":false,"backdrop_path":"\/bOGkgRGdhrBYJSLpXaxhXVstddV.jpg","original_language":"en","original_title":"Avengers: Infinity War","genre_ids":[28,12,878],"title":"Avengers: Infinity War","vote_average":8.3,"overview":"As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.","release_date":"2018-04-27"},{"popularity":39.437,"vote_count":13745,"video":false,"poster_path":"\/uxzzxijgP
# ...

# %%
data
# Out:
# b'{"page":1,"total_results":6367,"total_pages":319,"results":[{"popularity":84.433,"vote_count":15979,"video":false,"poster_path":"\\/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg","id":299536,"adult":false,"backdrop_path":"\\/bOGkgRGdhrBYJSLpXaxhXVstddV.jpg","original_language":"en","original_title":"Avengers: Infinity War","genre_ids":[28,12,878],"title":"Avengers: Infinity War","vote_average":8.3,"overview":"As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.","release_date":"2018-04-27"},{"popularity":39.437,"vote_count":13745,"video":false,"poster_path":"\\/uxzz
# ...

# %%
data1_dict=json.loads(data)
data1_dict
# Out:
# {'page': 1,
#  'total_results': 6367,
#  'total_pages': 319,
#  'results': [{'popularity': 84.433,
#    'vote_count': 15979,
#    'video': False,
#    'poster_path': '/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg',
#    'id': 299536,
#    'adult': False,
#    'backdrop_path': '/bOGkgRGdhrBYJSLpXaxhXVstddV.jpg',
#    'original_language': 'en',
#    'original_title': 'Avengers: Infinity War',
#    'genre_ids': [28, 12, 878],
#    'title': 'Avengers: Infinity War',
#    'vote_average': 8.3,
#    'overview': 'As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.',
# ...

# %%
data1_dict.keys()
# Out:
# dict_keys(['page', 'total_results', 'total_pages', 'results'])

# %%
data1_dict['results'][0]
# Out:
# {'popularity': 84.433,
#  'vote_count': 15979,
#  'video': False,
#  'poster_path': '/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg',
#  'id': 299536,
#  'adult': False,
#  'backdrop_path': '/bOGkgRGdhrBYJSLpXaxhXVstddV.jpg',
#  'original_language': 'en',
#  'original_title': 'Avengers: Infinity War',
#  'genre_ids': [28, 12, 878],
#  'title': 'Avengers: Infinity War',
#  'vote_average': 8.3,
#  'overview': 'As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.',
#  'release_date': '2018-04-27'}

# %% [markdown]
# ################################  Tuple Creation ################################

# %%
movie1 = data1_dict['results'][0]

# %%
movie_tuple = (movie1['id'], movie1['title'], movie1['release_date'], movie1['genre_ids'], movie1['popularity'], movie1['vote_average'], movie1['vote_count'])

# %%
movie_tuple
# Out:
# (299536,
#  'Avengers: Infinity War',
#  '2018-04-27',
#  [28, 12, 878],
#  84.433,
#  8.3,
#  15979)

# %%
def parse_data(data_list):
    parsed_data_list = []

    for movie in data_list['results']:
   # try:
        movie_tuple = (movie['id'], movie['title'], movie['release_date'], movie['genre_ids'], movie['popularity'], movie['vote_average'], movie['vote_count'])
        parsed_data_list.append(movie_tuple)
    return parsed_data_list

# %%
parse_data(data1_dict)
# Out:
# [(299536,
#   'Avengers: Infinity War',
#   '2018-04-27',
#   [28, 12, 878],
#   84.433,
#   8.3,
#   15979),
#  (284054,
#   'Black Panther',
#   '2018-02-16',
#   [28, 12, 14, 878],
#   39.437,
#   7.4,
#   13745),
#  (181808,
#   'Star Wars: The Last Jedi',
#   '2017-12-15',
#   [28, 12, 14, 878],
#   52.524,
#   7,
#   9304),
#  (351286,
#   'Jurassic World: Fallen Kingdom',
#   '2018-06-22',
#   [28, 12, 878],
#   26.414,
#   6.5,
#   6632),
#  (260513, 'Incredibles 2', '2018-06-15', [28, 12, 16, 10751], 22.7, 7.5, 7294),
#  (297802, 'Aquaman', '2018-12-21', [28, 12, 14], 29.244, 6.8, 7457),
#  (353486,
#   'Jumanji: Welcome to the Jungle',
#   '2017-12-20',
#   [28, 12, 35, 14],
#   26.474,
#   6.7,
#   7981),
#  (424694, 'Bohemian Rhapsody', '2018-11-02', [18, 10402], 37.758, 8, 9333),
#  (335983, 'Venom', '2018-10-05', [28, 878], 33.128, 6.6, 7527),
#  (284053,
#   'Thor: Ragnarok',
#   '2017-11-03',
#   [28, 12, 35, 14],
#   39.094,
#   7.5,
#   12596),
# ...

# %% [markdown]
# ##############################################################################################

# %% [markdown]
# ##############################################################################################

# %%
page = 1
#url = f"/3/discover/movie?year=2018&page={page}&include_video=false&include_adult=false&sort_by=revenue.desc&region=US&language=en-US&api_key=69b1bbc66e37773ea1cc0568b2898163"

# %%
import http.client
def api_call(url, page):
    conn = http.client.HTTPSConnection("api.themoviedb.org")

    payload = "{}"
    url = f"/3/discover/movie?year=2018&page={page}&include_video=false&include_adult=false&sort_by=revenue.desc&region=US&language=en-US&api_key=69b1bbc66e37773ea1cc0568b2898163"
    conn.request("GET", url, payload)

    res = conn.getresponse()
    data = res.read()

    
    data1_dict=json.loads(data)
    
    return data1_dict

# %%
test=api_call(url,15)

# %%
def parse_data(data_list):
    parsed_data_list = []

    for movie in data_list['results']:
        try:
            movie_tuple = (movie['id'], movie['title'], movie['release_date'], movie['genre_ids'][0], movie['popularity'], movie['vote_average'], movie['vote_count'])
            parsed_data_list.append(movie_tuple)
        except:
            movie_tuple = (movie['id'], movie['title'], movie['release_date'], 0, movie['popularity'], movie['vote_average'], movie['vote_count'])
            parsed_data_list.append(movie_tuple)
            
        
    return parsed_data_list

# %%
parse_data(test)
# Out:
# [(468735, "Madeline's Madeline", '2018-08-10', 18, 5.386, 6.3, 36),
#  (469062,
#   'Scotty and the Secret History of Hollywood',
#   '2018-07-27',
#   99,
#   3.111,
#   6.7,
#   13),
#  (401561, 'Mom and Dad', '2018-01-19', 35, 11.848, 5.2, 432),
#  (452226, 'The King', '2018-06-22', 99, 3.636, 6, 4),
#  (541576, 'Meeting Gorbachev', '2019-05-03', 99, 7.528, 8.4, 8),
#  (426284, 'Blade of the Immortal', '2017-11-03', 28, 11.4, 6.5, 226),
#  (401898, 'Thelma', '2017-11-10', 18, 13.465, 7.1, 402),
#  (502138, 'The World Before Your Feet', '2018-11-21', 99, 6, 7.7, 3),
#  (591461, 'The Dog Walker', '2018-11-11', 0, 0.6, 0, 0),
#  (429417, 'Ghost Stories', '2018-04-20', 18, 11.962, 6.5, 641),
#  (481880, 'Trial by Fire', '2019-05-17', 18, 9.198, 6.3, 22),
#  (456086, 'Support the Girls', '2018-08-24', 18, 7.939, 6.2, 68),
#  (566116, 'Deontay Wilder vs. Tyson Fury', '2018-12-01', 28, 0.672, 0, 0),
#  (416186, 'Godard Mon Amour', '2018-04-20', 35, 6.826, 6.8, 180),
# ...

# %%
def insert_into_db(cnx, cursor, parsed_data):
    stmt = "INSERT INTO data1 (movie_id, title, release_date, genre_ids, popularity, vote_avg, vote_count) VALUES (%s, %s, %s, %s, %s, %s, %s)"
    cursor.executemany(stmt, parsed_data)
    cnx.commit()

# %%
#def paginate(url):
for i in range(1,320): 
    print(i)
    page = i
    movies = api_call(url, page)
    print(movies)
    parsed_data = parse_data(movies)
    insert_into_db(cnx, cursor, parsed_data)
    page+=1
    time.sleep(10)
# Out:
# 310
# ...

# %%
#paginate(url)
