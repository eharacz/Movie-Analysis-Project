# %%
import numpy as np
import pandas as pd
import csv
df = pd.read_csv('Movie_Analysis_Project_data1.csv')

# %%
df
# Out:
#      movie_id                           title release_date  genre_ids  \
# 0      299536          Avengers: Infinity War   2018-04-27         28
# 1      284054                   Black Panther   2018-02-16         28
# 2      351286  Jurassic World: Fallen Kingdom   2018-06-22         28
# 3      260513                   Incredibles 2   2018-06-15         28
# 4      297802                         Aquaman   2018-12-21         28
# ..        ...                             ...          ...        ...
# 484    617221                    Touch Me Not   2018-08-03      10749
# 485    557660      Making The Five Heartbeats   2018-08-27         99
# 486    589665                    Out on Stage   2018-07-24          0
# 487    557179                The Lost Village   2018-10-19         99
# 488    557182     TVTV: Video Revolutionaries   2018-10-19         99
#
#      popularity  vote_avg  vote_count  genre_id        genre  Rank  \
# ...

# %%
df.set_index('movie_id')
# Out:
#                                    title release_date  genre_ids  popularity  \
# movie_id
# 299536            Avengers: Infinity War   2018-04-27         28      84.844
# 284054                     Black Panther   2018-02-16         28      43.492
# 351286    Jurassic World: Fallen Kingdom   2018-06-22         28      30.743
# 260513                     Incredibles 2   2018-06-15         28      27.087
# 297802                           Aquaman   2018-12-21         28      31.629
# ...                                  ...          ...        ...         ...
# 617221                      Touch Me Not   2018-08-03      10749       0.600
# 557660        Making The Five Heartbeats   2018-08-27         99       0.687
# 589665                      Out on Stage   2018-07-24          0       0.600
# 557179                  The Lost Village   2018-10-19         99       1.217
# 557182       TVTV: Video Revolutionaries   2018-10-19         99       0.600
#
# ...
